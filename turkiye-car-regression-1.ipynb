# %% [markdown]
# # Standart imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_data = pd.read_csv("data/turkey_car_market.csv")
car_data
# Out:
#      İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0     27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1     16/06/2020   Acura             CL                    -     2015.0
# 2     14/06/2020   Acura             CL                  2.2     1994.0
# 3     11/06/2020   Acura             CL                    -     2013.0
# 4     11/06/2020   Acura             CL                  2.2     2010.0
# ...          ...     ...            ...                  ...        ...
# 9039  06/06/2020   Tofaş          Şahin                  1.6     1994.0
# 9040  05/06/2020   Tofaş          Şahin        Şahin 5 vites     1992.0
# 9041  05/06/2020   Tofaş          Doğan                  SLX     1993.0
# 9042  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1991.0
# 9043  04/06/2020   Tofaş         Kartal       Kartal 5 Vites     1996.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# 0          Dizel       Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1          Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2     Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3          Dizel            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4          Dizel       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
# ...          ...                  ...           ...         ...          ...
# 9039  Benzin/LPG            Düz Vites  1301-1600 cc    51-75 BG       Beyaz
# 9040  Benzin/LPG            Düz Vites  1301-1600 cc   76-100 BG         Bej
# 9041  Benzin/LPG            Düz Vites  1301-1600 cc   76-100 BG       Yeşil
# 9042  Benzin/LPG            Düz Vites  1601-1800 cc   76-100 BG     Kırmızı
# 9043  Benzin/LPG            Düz Vites  1301-1600 cc    51-75 BG       Beyaz
#
#              Kasa Tipi      Kimden  Durum      Km   Fiyat
# 0     Hatchback 5 Kapı   Galeriden  2. El   26100  634500
# 1                Sedan  Sahibinden  2. El  127000  151500
# 2                Sedan  Sahibinden  2. El  175000   19750
# 3                Sedan  Sahibinden  2. El     325   52000
# 4                Sedan  Sahibinden  2. El  207000  148750
# ...                ...         ...    ...     ...     ...
# 9039             Sedan   Galeriden  2. El  121212   12250
# 9040             Sedan  Sahibinden  2. El   54000   16300
# 9041             Sedan  Sahibinden  2. El  135000   19000
# 9042  Hatchback 5 Kapı   Galeriden  2. El  250000   11000
# 9043             Sedan   Galeriden  2. El      11   15750
#
# [9044 rows x 15 columns]

# %%
# Check datatypes for each column
car_data.dtypes
# Out:
# İlan Tarihi        object
# Marka              object
# Arac Tip Grubu     object
# Arac Tip           object
# Model Yıl         float64
# Yakıt Turu         object
# Vites              object
# CCM                object
# Beygir Gucu        object
# Renk               object
# Kasa Tipi          object
# Kimden             object
# Durum              object
# Km                  int64
# Fiyat               int64
# dtype: object

# %%
# convert column "Model Yılı" to int64 dtype
car_data = car_data.astype({"Model Yıl": int})
car_data.dtypes
# Out:
# İlan Tarihi       object
# Marka             object
# Arac Tip Grubu    object
# Arac Tip          object
# Model Yıl          int64
# Yakıt Turu        object
# Vites             object
# CCM               object
# Beygir Gucu       object
# Renk              object
# Kasa Tipi         object
# Kimden            object
# Durum             object
# Km                 int64
# Fiyat              int64
# dtype: object

# %%
# Check missing values
car_data.isna().sum()
# Out:
# İlan Tarihi       0
# Marka             0
# Arac Tip Grubu    0
# Arac Tip          0
# Model Yıl         0
# Yakıt Turu        0
# Vites             0
# CCM               0
# Beygir Gucu       0
# Renk              0
# Kasa Tipi         0
# Kimden            0
# Durum             0
# Km                0
# Fiyat             0
# dtype: int64

# %%
# It is not a time series data so delete the column "İlan Tarihi"
car_data = car_data.drop("İlan Tarihi", axis=1)
car_data
# Out:
#        Marka Arac Tip Grubu             Arac Tip  Model Yıl  Yakıt Turu  \
# 0     Jaguar             XF  2.0 D Prestige Plus       2017       Dizel
# 1      Acura             CL                    -       2015       Dizel
# 2      Acura             CL                  2.2       1994  Benzin/LPG
# 3      Acura             CL                    -       2013       Dizel
# 4      Acura             CL                  2.2       2010       Dizel
# ...      ...            ...                  ...        ...         ...
# 9039   Tofaş          Şahin                  1.6       1994  Benzin/LPG
# 9040   Tofaş          Şahin        Şahin 5 vites       1992  Benzin/LPG
# 9041   Tofaş          Doğan                  SLX       1993  Benzin/LPG
# 9042   Tofaş         Kartal       Kartal 5 Vites       1991  Benzin/LPG
# 9043   Tofaş         Kartal       Kartal 5 Vites       1996  Benzin/LPG
#
#                     Vites           CCM Beygir Gucu         Renk  \
# 0          Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1     Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2               Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3               Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4          Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
# ...                   ...           ...         ...          ...
# 9039            Düz Vites  1301-1600 cc    51-75 BG       Beyaz
# 9040            Düz Vites  1301-1600 cc   76-100 BG         Bej
# 9041            Düz Vites  1301-1600 cc   76-100 BG       Yeşil
# 9042            Düz Vites  1601-1800 cc   76-100 BG     Kırmızı
# 9043            Düz Vites  1301-1600 cc    51-75 BG       Beyaz
#
#              Kasa Tipi      Kimden  Durum      Km   Fiyat
# 0     Hatchback 5 Kapı   Galeriden  2. El   26100  634500
# 1                Sedan  Sahibinden  2. El  127000  151500
# 2                Sedan  Sahibinden  2. El  175000   19750
# 3                Sedan  Sahibinden  2. El     325   52000
# 4                Sedan  Sahibinden  2. El  207000  148750
# ...                ...         ...    ...     ...     ...
# 9039             Sedan   Galeriden  2. El  121212   12250
# 9040             Sedan  Sahibinden  2. El   54000   16300
# 9041             Sedan  Sahibinden  2. El  135000   19000
# 9042  Hatchback 5 Kapı   Galeriden  2. El  250000   11000
# 9043             Sedan   Galeriden  2. El      11   15750
#
# [9044 rows x 14 columns]

# %%
# Shuffle the data
np.random.seed(27)
car_data = car_data.sample(frac=1)
car_data
# Out:
#            Marka Arac Tip Grubu                Arac Tip  Model Yıl  \
# 2815        Ford          Focus        1.6 TDCi Trend X       2013
# 7722     Renault         Captur            1.5 dCi Icon       2018
# 4465    Mercedes       E Serisi  E 200 Komp. Avantgarde       2008
# 715          BMW       5 Serisi    525d xDrive  Premium       2015
# 8647        Seat           Leon           1.6 TDI Style       2016
# ...          ...            ...                     ...        ...
# 4043         Kia       Sportage            2.0 CRDi 2.0       2010
# 4157  Land Rover          Diğer                   Diğer       2017
# 6797     Renault           Clio                 1.2 Joy       2019
# 6770     Renault         Symbol     1.5 dCi Authentique       2011
# 6437     Renault       Broadway                Broadway       1997
#
#       Yakıt Turu                Vites              CCM     Beygir Gucu  \
# 2815       Dizel            Düz Vites     1301-1600 cc      Bilmiyorum
# 7722       Dizel  Yarı Otomatik Vites     1301-1600 cc      Bilmiyorum
# 4465      Benzin       Otomatik Vites     1601-1800 cc      Bilmiyorum
# 715        Dizel  Yarı Otomatik Vites     1801-2000 cc      Bilmiyorum
# 8647       Dizel  Yarı Otomatik Vites     1301-1600 cc      Bilmiyorum
# ...          ...                  ...              ...             ...
# 4043       Dizel       Otomatik Vites     1801-2000 cc      Bilmiyorum
# 4157       Dizel       Otomatik Vites     1801-2000 cc      Bilmiyorum
# 6797      Benzin            Düz Vites  1300 cc ve altı        51-75 BG
# 6770       Dizel            Düz Vites     1301-1600 cc  100 BG ve altı
# 6437  Benzin/LPG            Düz Vites     1301-1600 cc        51-75 BG
#
#           Renk         Kasa Tipi     Kimden  Durum      Km   Fiyat
# 2815      Gri              Sedan  Galeriden  2. El  244000   72500
# 7722  Kırmızı        Arazi Aracı  Galeriden  2. El   94000  156500
# 4465    Siyah              Sedan  Galeriden  2. El  197331  189500
# 715     Beyaz              Sedan  Galeriden  2. El  144000  359000
# 8647    Beyaz   Hatchback 5 Kapı  Galeriden  2. El   97000  154900
# ...        ...               ...        ...    ...     ...     ...
# 4043    Siyah        Arazi Aracı  Galeriden  2. El  126000  112000
# 4157    Beyaz        Arazi Aracı  Galeriden  2. El   55000  445000
# 6797    Beyaz   Hatchback 5 Kapı  Galeriden  2. El    9600   98000
# 6770    Beyaz              Sedan  Galeriden  2. El  270000   46750
# 6437     Mavi              Sedan  Galeriden  2. El  235000   22000
#
# [9044 rows x 14 columns]

# %%
# Split data into X & y
X = car_data.drop("Fiyat", axis=1)
y = car_data["Fiyat"]

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer # this will help us fill missing values
from sklearn.preprocessing import OneHotEncoder # this will help us turn our categorical variables into numbers

# Define categorical columns
categorical_features = ["Marka", "Arac Tip Grubu", "Arac Tip", "Yakıt Turu", "Vites", "CCM",
                        "Beygir Gucu", "Renk", "Kasa Tipi", "Kimden", "Durum"]

# Create categorical transformer (imputes missing values, then one hot encodes them)
# For this instance there is no missing values
categorical_transofrmer = Pipeline(steps=[
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# Define numeric features
numerical_features = ["Model Yıl", "Km"]
# Dont need to define numeric features because it's already numeric and there is no missing values
# But we will use it to sake of order
numerical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean"))
])

# %%
from sklearn.compose import ColumnTransformer

# Create a column transformer which combines all of the other transformer into one step
preprocessor = ColumnTransformer(
    transformers=[
        # (name, transformer_to_use, features_to_use transform)
        ("categorical", categorical_transofrmer, categorical_features),
        ("numerical", numerical_transformer, numerical_features)
    ])

# %%
from sklearn.ensemble import RandomForestRegressor

# Create the preprocessing and modelling pipeline
model = Pipeline(steps=[("preprocessor", preprocessor), # this will fill our missing data and make sure it's all numbers
                       ("regressor", RandomForestRegressor())]) # this will model our data

# %%
from sklearn.model_selection import train_test_split

# Split data into train and test test
np.random.seed(27)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit the model on the training data
# note when fit() is called with a Pipeline(), fit_transform() is used for transformes
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Marka', 'Arac Tip Grubu',
#                                                    'Arac Tip', 'Yakıt Turu',
#                                                    'Vites', 'CCM',
#                                                    'Beygir Gucu', 'Renk',
#                                                    'Kasa Tipi', 'Kimden',
#                                                    'Durum']),
#                                                  ('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Model Yıl', 'Km'])])),
#                 ('regressor', RandomForestRegressor())])

# %%
# Score the model on the data
# note: when score() or predict() is called with Pipeline(), transform() is used for transformers
model.score(X_test, y_test)
# Out:
# 0.675581687188068

# %%
car_data.dtypes
# Out:
# Marka             object
# Arac Tip Grubu    object
# Arac Tip          object
# Model Yıl          int64
# Yakıt Turu        object
# Vites             object
# CCM               object
# Beygir Gucu       object
# Renk              object
# Kasa Tipi         object
# Kimden            object
# Durum             object
# Km                 int64
# Fiyat              int64
# dtype: object

# %%
from sklearn.model_selection import cross_val_score

# Cross-validate our pipeline model
cross_val_score(model, X, y).mean()
